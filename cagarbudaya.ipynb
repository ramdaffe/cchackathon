# %%
import pandas as pd
import requests
import json

# %%
PROVINCES_CODE = []
base_query = 'http://jendela.data.kemdikbud.go.id/api/index.php/CcariCagarBudaya/searchGET?kode_prop='

# %%
resp = requests.get('http://jendela.data.kemdikbud.go.id/api/index.php/CWilayah/wilayahGET')
data = json.loads(resp.text)

# %%
# Out:
# {u'data': [{u'alamat_jalan': u'-',
#    u'batas_barat': u'-',
#    u'batas_selatan': u'-',
#    u'batas_timur': u'-',
#    u'batas_utara': u'-',
#    u'bujur': u'123.5041770',
#    u'cagar_budaya_id': u'24C7159E-ABD4-4DC2-8BFF-4CB510089C7E',
#    u'desa_kelurahan': u'Lompio',
#    u'kabupaten_kota': u'Kab. Banggai Laut',
#    u'kecamatan': u'Kec. Banggai',
#    u'kode_pengelolaan': u'KB000781',
#    u'lintang': u'-1.5933270',
#    u'nama': u'Bekas Istana Raja Banggai',
#    u'nomor_penetapan': u'KM.11/PW.007/MKP/03',
#    u'pemilik': u'Negara (Pemerintah Daerah Tk II Kabupaten Banggai)',
#    u'pengelola': u'-',
#    u'propinsi': u'Prop. Sulawesi Tengah',
#    u'tanggal_penetapan': u'2003-03-04 00:00:00.000'},
#   {u'alamat_jalan': u'-',
#    u'batas_barat': u'Desa Eteng dan Desa Minagandala',
#    u'batas_selatan': u'Desa Tangi',
#    u'batas_timur': u'Desa Kospakarya',
#    u'batas_utara': u'Desa Binsil',
#    u'bujur': u'123.2361170',
#    u'cagar_budaya_id': u'C8F816EF-2197-4458-9D20-1AD0372C3154',
#    u'desa_kelurahan': u'Simpangan',
#    u'kabupaten_kota': u'Kab. Banggai',
#    u'kecamatan': u'Kec. Lamala',
#    u'kode_pengelolaan': u'KB000778',
#    u'lintang': u'-.7722810',
#    u'nama': u'Gereja Tua Simpangan',
#    u'nomor_penetapan': u'KM.11/PW.007/MKP/03',
#    u'pemilik': u'Negara (Depdiknas)',
#    u'pengelola': u'-',
#    u'propinsi': u'Prop. Sulawesi Tengah',
#    u'tanggal_penetapan': u'2003-03-04 00:00:00.000'},
#   {u'alamat_jalan': u'-',
#    u'batas_barat': u'Rumah Penduduk',
#    u'batas_selatan': u'Jalan Desa',
#    u'batas_timur': u'Jalan Setapak dan Rumah Penduduk',
#    u'batas_utara': u'Kebun dan Rumah Penduduk',
#    u'bujur': u'121.3345390',
#    u'cagar_budaya_id': u'3DB5E8A5-FBB5-4292-839A-C1F9878D290F',
#    u'desa_kelurahan': u'Kolonodale',
#    u'kabupaten_kota': u'Kab. Morowali Utara',
#    u'kecamatan': u'Kec. Petasia',
#    u'kode_pengelolaan': u'KB001678',
#    u'lintang': u'-2.0187070',
#    u'nama': u'Istana Raja Mori',
#    u'nomor_penetapan': u'KM.11/PW.007/MKP/03',
#    u'pemilik': u'Negara (Pemerintah Daerah Tk II Kabupaten Poso)',
#    u'pengelola': u'-',
#    u'propinsi': u'Prop. Sulawesi Tengah',
#    u'tanggal_penetapan': u'2003-03-04 00:00:00.000'},
#   {u'alamat_jalan': u'-',
#    u'batas_barat': u'Hutan Kecil',
#    u'batas_selatan': u'Lambara',
#    u'batas_timur': u'Hutan Kecil',
#    u'batas_utara': u'Lambara',
#    u'bujur': u'120.2959440',
#    u'cagar_budaya_id': u'2AF6BF94-FC57-4860-BFFF-2F2BDB411F59',
#    u'desa_kelurahan': u'Beririr',
#    u'kabupaten_kota': u'Kab. Poso',
#    u'kecamatan': u'Kec. Lore Utara',
#    u'kode_pengelolaan': u'KB000780',
#    u'lintang': u'-1.2441040',
#    u'nama': u'Kompleks Megalit Padang Pokekea',
#    u'nomor_penetapan': u'KM.11/PW.007/MKP/03',
#    u'pemilik': u'-',
#    u'pengelola': u'-',
#    u'propinsi': u'Prop. Sulawesi Tengah',
#    u'tanggal_penetapan': u'2003-03-04 00:00:00.000'},
#   {u'alamat_jalan': u'-',
#    u'batas_barat': u'Komplek Makam',
#    u'batas_selatan': u'Perkampungan',
#    u'batas_timur': u'Jalan Raya dan Laut',
#    u'batas_utara': u'Bekas Istana Bungku',
#    u'bujur': u'121.9705560',
#    u'cagar_budaya_id': u'C68B503F-F1C5-4517-9776-A6D928E91E19',
#    u'desa_kelurahan': u'Marsaole',
#    u'kabupaten_kota': u'Kab. Morowali',
#    u'kecamatan': u'Kec. Bungku Tengah',
#    u'kode_pengelolaan': u'KB000779',
#    u'lintang': u'-2.5441670',
#    u'nama': u'Masjid Tua Bungku',
#    u'nomor_penetapan': u'KM.11/PW.007/MKP/03',
#    u'pemilik': u'-',
#    u'pengelola': u'-',
#    u'propinsi': u'Prop. Sulawesi Tengah',
#    u'tanggal_penetapan': u'2003-03-04 00:00:00.000'}]}

# %%
result = []
for i in PROVINCES_CODE:
    print i
    resp = requests.get(base_query+i)
    data = json.loads(resp.text)
    result.append(data['data'])
# Out:
# 010000
# 020000
# 030000
# 040000
# 050000
# 060000
# 070000
# 080000
# 090000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000

# %%
res_all = [item for sublist in result for item in sublist]
df = pd.DataFrame(res_all)

# %%
df.head()
# Out:
#                  alamat_jalan batas_barat batas_selatan batas_timur  \
# 0  Jl. Merdeka Barat Nomor 12           -             -           -
# 1  Jl. Merdeka Barat Nomor 12           -             -           -
# 2                           -        None          None        None
# 3     Jl. Imam Bonjol Nomor 1        None          None        None
# 4   Jl. Kramat Raya Nomor 106        None          None        None
#
#   batas_utara        bujur                       cagar_budaya_id  \
# 0           -  106.8214540  6E213149-5902-4E29-AF11-B0F765D0D517
# 1           -  106.8217740  44AF3736-D7BD-4C05-8619-45E7D66078BC
# 2        None  106.8672000  D042B3EB-E051-4039-8B5F-705644E39D12
# 3        None  106.8310110  3BC709F0-72BD-4860-A45F-B24BCDE17766
# 4        None  106.8432240  C306B161-DB0F-4697-ADF0-ED9B37E7116F
#
#   desa_kelurahan      kabupaten_kota        kecamatan kode_pengelolaan  \
# 0         Gambir  Kota Jakarta Pusat      Kec. Gambir         KB000943
# 1         Gambir  Kota Jakarta Pusat      Kec. Gambir         KB000953
# 2    Bidara Cina  Kota Jakarta Timur  Kec. Jatinegara         KB000125
# 3        Menteng  Kota Jakarta Pusat     Kec. Menteng         KB000955
# 4        Kwitang  Kota Jakarta Pusat       Kec. Senen         KB000956
#
#       lintang                                               nama  \
# 0  -6.1765550                                      Arca Bhairawa
# 1  -6.1763100                               Arca Prajnyaparamita
# 2  -6.2187640  Bangunan Pusat Pendidikan dan Latihan Bank Rak...
# 3  -6.2004280  Bangunan Utama Gedung Museum Perumusan Naskah ...
# 4  -6.1837130         Bangunan Utama Gedung Museum Sumpah Pemuda
#
#            nomor_penetapan pemilik        pengelola              propinsi  \
# 0               024/M/2014  Negara  Museum Nasional  Prop. D.K.I. Jakarta
# 1               251/M/2013  Negara  Museum Nasional  Prop. D.K.I. Jakarta
# 2  Kepmen Nomor 011/M/1999    None             None  Prop. D.K.I. Jakarta
# 3  Kepmen Nomor 253/M/2013    None             None  Prop. D.K.I. Jakarta
# 4  Kepmen Nomor 254/M/2013    None             None  Prop. D.K.I. Jakarta
#
#          tanggal_penetapan
# 0  2014-01-17 00:00:00.000
# 1  2013-12-27 00:00:00.000
# 2                     None
# 3                     None
# 4                     None

# %%
df.to_csv('cagarbudaya.csv',encoding='utf-8')
